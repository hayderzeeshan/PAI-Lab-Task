# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.11.0

# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/104.6 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/104.6 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/104.6 kB 217.9 kB/s eta 0:00:01
#      --------------------- --------------- 61.4/104.6 kB 273.8 kB/s eta 0:00:01
#      -----------------------------------  102.4/104.6 kB 393.8 kB/s eta 0:00:01
#      ------------------------------------ 104.6/104.6 kB 354.8 kB/s eta 0:00:00
# ...

# %%
# Getting Started
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.11.0

# %% [markdown]
# # Working with Images

# %%
image = cv2.imread('image.png')  
if image is None:
    raise FileNotFoundError("Image not found!")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %% [markdown]
# # Image Processing

# %%
# 1
resized = cv2.resize(image_rgb, (300, 300))
# 2
gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
# 3
blurred = cv2.GaussianBlur(image_rgb, (7, 7), 0)
# 4
edges = cv2.Canny(gray, 100, 200)

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(gray, cmap='gray')
axs[0].set_title("Grayscale")
axs[1].imshow(blurred)
axs[1].set_title("Blurred")
axs[2].imshow(edges, cmap='gray')
axs[2].set_title("Canny Edges")
for ax in axs: ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Feature Detection and Description (ORB)

# %%
# 1
gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
# 2
orb = cv2.ORB_create()
# 3
keypoints, descriptors = orb.detectAndCompute(gray, None)
# 4
feature_img = cv2.drawKeypoints(image_rgb, keypoints, None, color=(0, 255, 0))

# %%
plt.imshow(feature_img)
plt.title("ORB Feature Keypoints")
plt.axis("off")
plt.show()

# %% [markdown]
# #  Drawing Functions (Line, Rectangle, Circle, Text)

# %%
# 1
canvas = image_rgb.copy()
# 2
cv2.line(canvas, (50, 50), (250, 50), (255, 0, 0), 3)
# 3
cv2.rectangle(canvas, (60, 60), (240, 240), (0, 255, 0), 2)
# 4
cv2.circle(canvas, (150, 150), 40, (0, 0, 255), -1)
# 5
cv2.putText(canvas, "OpenCV Rocks", (50, 280), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 0), 2)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(canvas)
plt.title("Drawing Shapes and Text")
plt.axis("off")
plt.show()
